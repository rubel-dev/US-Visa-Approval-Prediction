# %%
print('hello')
# Out:
# hello

# %%
import pandas as pd
df1 = pd.read_csv('Easyvisa.csv')
df1.head()
# Out:
# Failed to start the Kernel.
#
# Unable to start Kernel 'visa (Python 3.12.12)' due to a timeout waiting for the ports to get used.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.

# %%
data = df1.to_dict(orient='records')

# %%
DB_NAME = 'US_VISA'
COLLECTION_NAME = 'visa_data'
CONNECTION_URL = "mongodb+srv://rubel:rubel1234@cluster0.ot2uzux.mongodb.net/?appName=Cluster0"

# %%
import pymongo

# %%
client = pymongo.MongoClient(CONNECTION_URL)
data_base = client[DB_NAME]
collection = data_base[COLLECTION_NAME]
rec = collection.insert_many(data)
# Out:
# ---------------------------------------------------------------------------
# SSLEOFError                               Traceback (most recent call last)
# File c:\Users\Rubel\anaconda3\envs\visa\Lib\site-packages\pymongo\synchronous\pool.py:455, in Connection.send_message(self, message, max_doc_size)
#     454 try:
# --> 455     sendall(self.conn.get_conn, message)
#     456 # Catch KeyboardInterrupt, CancelledError, etc. and cleanup.
#
# File c:\Users\Rubel\anaconda3\envs\visa\Lib\site-packages\pymongo\network_layer.py:239, in sendall(sock, buf)
#     238 def sendall(sock: Union[socket.socket, _sslConn], buf: bytes) -> None:
# --> 239     sock.sendall(buf)
#
# File c:\Users\Rubel\anaconda3\envs\visa\Lib\ssl.py:1210, in SSLSocket.sendall(self, data, flags)
#    1209 while count < amount:
# -> 1210     v = self.send(byte_view[count:])
#    1211     count += v
#
# File c:\Users\Rubel\anaconda3\envs\visa\Lib\ssl.py:1179, in SSLSocket.send(self, data, flags)
#    1176         raise ValueError(
#    1177             "non-zero flags not allowed in calls to send() on %s" %
#    1178             self.__class__)
# -> 1179     return self._sslobj.write(data)
#    1180 else:
#
# SSLEOFError: EOF occurred in violation of protocol (_ssl.c:2427)
#
# The above exception was the direct cause of the following exception:
#
# AutoReconnect                             Traceback (most recent call last)
# Cell In[21], line 4
#       2 data_base = client[DB_NAME]
#       3 collection = data_base[COLLECTION_NAME]
# ----> 4 rec = collection.insert_many(data)
#
# File c:\Users\Rubel\anaconda3\envs\visa\Lib\site-packages\pymongo\_csot.py:125, in apply.<locals>.csot_wrapper(self, *args, **kwargs)
#     123         with _TimeoutContext(timeout):
#     124             return func(self, *args, **kwargs)
# --> 125 return func(self, *args, **kwargs)
#
# File c:\Users\Rubel\anaconda3\envs\visa\Lib\site-packages\pymongo\synchronous\collection.py:975, in Collection.insert_many(self, documents, ordered, bypass_document_validation, session, comment)
#     973 blk = _Bulk(self, ordered, bypass_document_validation, comment=comment)
#     974 blk.ops = list(gen())
# --> 975 blk.execute(write_concern, session, _Op.INSERT)
#     976 return InsertManyResult(inserted_ids, write_concern.acknowledged)
#
# File c:\Users\Rubel\anaconda3\envs\visa\Lib\site-packages\pymongo\synchronous\bulk.py:751, in _Bulk.execute(self, write_concern, session, operation)
#     749         return None
#     750 else:
# --> 751     return self.execute_command(generator, write_concern, session, operation)
#
# File c:\Users\Rubel\anaconda3\envs\visa\Lib\site-packages\pymongo\synchronous\bulk.py:604, in _Bulk.execute_command(self, generator, write_concern, session, operation)
#     593     self._execute_command(
#     594         generator,
#     595         write_concern,
#    (...)    600         full_result,
#     601     )
#     603 client = self.collection.database.client
# --> 604 _ = client._retryable_write(
#     605     self.is_retryable,
#     606     retryable_bulk,
#     607     session,
#     608     operation,
#     609     bulk=self,  # type: ignore[arg-type]
#     610     operation_id=op_id,
#     611 )
#     613 if full_result["writeErrors"] or full_result["writeConcernErrors"]:
#     614     _raise_bulk_write_error(full_result)
#
# File c:\Users\Rubel\anaconda3\envs\visa\Lib\site-packages\pymongo\synchronous\mongo_client.py:2082, in MongoClient._retryable_write(self, retryable, func, session, operation, bulk, operation_id)
#    2068 """Execute an operation with consecutive retries if possible
#    2069
#    2070 Returns func()'s return value on success. On error retries the same
#    (...)   2079 :param bulk: bulk abstraction to execute operations in bulk, defaults to None
#    2080 """
#    2081 with self._tmp_session(session) as s:
# -> 2082     return self._retry_with_session(retryable, func, s, bulk, operation, operation_id)
#
# File c:\Users\Rubel\anaconda3\envs\visa\Lib\site-packages\pymongo\synchronous\mongo_client.py:1968, in MongoClient._retry_with_session(self, retryable, func, session, bulk, operation, operation_id)
#    1963 # Ensure that the options supports retry_writes and there is a valid session not in
#    1964 # transaction, otherwise, we will not support retry behavior for this txn.
#    1965 retryable = bool(
#    1966     retryable and self.options.retry_writes and session and not session.in_transaction
#    1967 )
# -> 1968 return self._retry_internal(
#    1969     func=func,
#    1970     session=session,
#    1971     bulk=bulk,
#    1972     operation=operation,
#    1973     retryable=retryable,
#    1974     operation_id=operation_id,
#    1975 )
#
# File c:\Users\Rubel\anaconda3\envs\visa\Lib\site-packages\pymongo\_csot.py:125, in apply.<locals>.csot_wrapper(self, *args, **kwargs)
#     123         with _TimeoutContext(timeout):
#     124             return func(self, *args, **kwargs)
# --> 125 return func(self, *args, **kwargs)
#
# File c:\Users\Rubel\anaconda3\envs\visa\Lib\site-packages\pymongo\synchronous\mongo_client.py:2014, in MongoClient._retry_internal(self, func, session, bulk, operation, is_read, address, read_pref, retryable, operation_id)
#    1977 @_csot.apply
#    1978 def _retry_internal(
#    1979     self,
#    (...)   1988     operation_id: Optional[int] = None,
#    1989 ) -> T:
#    1990     """Internal retryable helper for all client transactions.
#    1991
#    1992     :param func: Callback function we want to retry
#    (...)   2001     :return: Output of the calling func()
#    2002     """
#    2003     return _ClientConnectionRetryable(
#    2004         mongo_client=self,
#    2005         func=func,
#    2006         bulk=bulk,
#    2007         operation=operation,
#    2008         is_read=is_read,
#    2009         session=session,
#    2010         read_pref=read_pref,
#    2011         address=address,
#    2012         retryable=retryable,
#    2013         operation_id=operation_id,
# -> 2014     ).run()
#
# File c:\Users\Rubel\anaconda3\envs\visa\Lib\site-packages\pymongo\synchronous\mongo_client.py:2765, in _ClientConnectionRetryable.run(self)
#    2763 self._check_last_error(check_csot=True)
#    2764 try:
# -> 2765     return self._read() if self._is_read else self._write()
#    2766 except ServerSelectionTimeoutError:
#    2767     # The application may think the write was never attempted
#    2768     # if we raise ServerSelectionTimeoutError on the retry
#    2769     # attempt. Raise the original exception instead.
#    2770     self._check_last_error()
#
# File c:\Users\Rubel\anaconda3\envs\visa\Lib\site-packages\pymongo\synchronous\mongo_client.py:2897, in _ClientConnectionRetryable._write(self)
#    2889         if self._retrying:
#    2890             _debug_log(
#    2891                 _COMMAND_LOGGER,
#    2892                 message=f"Retrying write attempt number {self._attempt_number}",
#    (...)   2895                 operationId=self._operation_id,
#    2896             )
# -> 2897         return self._func(self._session, conn, self._retryable)  # type: ignore
#    2898 except PyMongoError as exc:
#    2899     if not self._retryable:
#
# File c:\Users\Rubel\anaconda3\envs\visa\Lib\site-packages\pymongo\synchronous\bulk.py:593, in _Bulk.execute_command.<locals>.retryable_bulk(session, conn, retryable)
#     590 def retryable_bulk(
#     591     session: Optional[ClientSession], conn: Connection, retryable: bool
#     592 ) -> None:
# --> 593     self._execute_command(
#     594         generator,
#     595         write_concern,
#     596         session,
#     597         conn,
#     598         op_id,
#     599         retryable,
#     600         full_result,
#     601     )
#
# File c:\Users\Rubel\anaconda3\envs\visa\Lib\site-packages\pymongo\synchronous\bulk.py:538, in _Bulk._execute_command(self, generator, write_concern, session, conn, op_id, retryable, full_result, final_write_concern)
#     536 # Run as many ops as possible in one command.
#     537 if write_concern.acknowledged:
# --> 538     result, to_send = self._execute_batch(bwc, cmd, ops, client)
#     540     # Retryable writeConcernErrors halt the execution of this run.
#     541     wce = result.get("writeConcernError", {})
#
# File c:\Users\Rubel\anaconda3\envs\visa\Lib\site-packages\pymongo\synchronous\bulk.py:462, in _Bulk._execute_batch(self, bwc, cmd, ops, client)
#     460 else:
#     461     request_id, msg, to_send = bwc.batch_command(cmd, ops)
# --> 462     result = self.write_command(bwc, cmd, request_id, msg, to_send, client)  # type: ignore[arg-type]
#     464 return result, to_send
#
# File c:\Users\Rubel\anaconda3\envs\visa\Lib\site-packages\pymongo\synchronous\helpers.py:47, in _handle_reauth.<locals>.inner(*args, **kwargs)
#      44 from pymongo.synchronous.pool import Connection
#      46 try:
# ---> 47     return func(*args, **kwargs)
#      48 except OperationFailure as exc:
#      49     if no_reauth:
#
# File c:\Users\Rubel\anaconda3\envs\visa\Lib\site-packages\pymongo\synchronous\bulk.py:274, in _Bulk.write_command(self, bwc, cmd, request_id, msg, docs, client)
#     272     bwc._start(cmd, request_id, docs)
#     273 try:
# --> 274     reply = bwc.conn.write_command(request_id, msg, bwc.codec)  # type: ignore[misc]
#     275     duration = datetime.datetime.now() - bwc.start_time
#     276     if _COMMAND_LOGGER.isEnabledFor(logging.DEBUG):
#
# File c:\Users\Rubel\anaconda3\envs\visa\Lib\site-packages\pymongo\synchronous\pool.py:500, in Connection.write_command(self, request_id, msg, codec_options)
#     490 def write_command(
#     491     self, request_id: int, msg: bytes, codec_options: CodecOptions[Mapping[str, Any]]
#     492 ) -> dict[str, Any]:
#     493     """Send "insert" etc. command, returning response as a dict.
#     494
#     495     Can raise ConnectionFailure or OperationFailure.
#    (...)    498     :param msg: bytes, the command message.
#     499     """
# --> 500     self.send_message(msg, 0)
#     501     reply = self.receive_message(request_id)
#     502     result = reply.command_response(codec_options)
#
# File c:\Users\Rubel\anaconda3\envs\visa\Lib\site-packages\pymongo\synchronous\pool.py:458, in Connection.send_message(self, message, max_doc_size)
#     456 # Catch KeyboardInterrupt, CancelledError, etc. and cleanup.
#     457 except BaseException as error:
# --> 458     self._raise_connection_failure(error)
#
# File c:\Users\Rubel\anaconda3\envs\visa\Lib\site-packages\pymongo\synchronous\pool.py:643, in Connection._raise_connection_failure(self, error)
#     641 if isinstance(error, (IOError, OSError, *SSLErrors)):
#     642     details = _get_timeout_details(self.opts)
# --> 643     _raise_connection_failure(self.address, error, timeout_details=details)
#     644 else:
#     645     raise
#
# File c:\Users\Rubel\anaconda3\envs\visa\Lib\site-packages\pymongo\pool_shared.py:150, in _raise_connection_failure(address, error, msg_prefix, timeout_details)
#     148     raise NetworkTimeout(msg) from error
#     149 else:
# --> 150     raise AutoReconnect(msg) from error
#
# AutoReconnect: ac-s2phry7-shard-00-01.ot2uzux.mongodb.net:27017: EOF occurred in violation of protocol (_ssl.c:2427) (configured timeouts: connectTimeoutMS: 20000.0ms)

# %%
df = pd.DataFrame(list(collection.find()))
df.head()
# Out:
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# File c:\Users\Rubel\anaconda3\envs\visa\Lib\site-packages\pymongo\synchronous\pool.py:466, in Connection.receive_message(self, request_id)
#     465 try:
# --> 466     return receive_message(self, request_id, self.max_message_size)
#     467 # Catch KeyboardInterrupt, CancelledError, etc. and cleanup.
#
# File c:\Users\Rubel\anaconda3\envs\visa\Lib\site-packages\pymongo\network_layer.py:778, in receive_message(conn, request_id, max_message_size)
#     777 else:
# --> 778     data = receive_data(conn, length - 16, deadline)
#     780 try:
#
# File c:\Users\Rubel\anaconda3\envs\visa\Lib\site-packages\pymongo\network_layer.py:379, in receive_data(conn, length, deadline)
#     378 if chunk_length == 0:
# --> 379     raise OSError("connection closed")
#     381 bytes_read += chunk_length
#
# OSError: connection closed
#
# The above exception was the direct cause of the following exception:
#
# AutoReconnect                             Traceback (most recent call last)
# Cell In[15], line 1
# ----> 1 df = pd.DataFrame(list(collection.find()))
#       2 df.head()
#
# File c:\Users\Rubel\anaconda3\envs\visa\Lib\site-packages\pymongo\synchronous\cursor.py:1289, in Cursor.__next__(self)
#    1288 def __next__(self) -> _DocumentType:
# -> 1289     return self.next()
#
# File c:\Users\Rubel\anaconda3\envs\visa\Lib\site-packages\pymongo\synchronous\cursor.py:1265, in Cursor.next(self)
#    1263 if self._empty:
#    1264     raise StopIteration
# -> 1265 if len(self._data) or self._refresh():
#    1266     return self._data.popleft()
#    1267 else:
#
# File c:\Users\Rubel\anaconda3\envs\visa\Lib\site-packages\pymongo\synchronous\cursor.py:1236, in Cursor._refresh(self)
#    1221     # Exhaust cursors don't send getMore messages.
#    1222     g = self._getmore_class(
#    1223         self._dbname,
#    1224         self._collname,
#    (...)   1234         self._comment,
#    1235     )
# -> 1236     self._send_message(g)
#    1238 return len(self._data)
#
# File c:\Users\Rubel\anaconda3\envs\visa\Lib\site-packages\pymongo\synchronous\cursor.py:1108, in Cursor._send_message(self, operation)
#    1105     raise InvalidOperation("exhaust cursors do not support auto encryption")
#    1107 try:
# -> 1108     response = client._run_operation(
#    1109         operation, self._unpack_response, address=self._address
#    1110     )
#    1111 except OperationFailure as exc:
#    1112     if exc.code in _CURSOR_CLOSED_ERRORS or self._exhaust:
#    1113         # Don't send killCursors because the cursor is already closed.
#
# File c:\Users\Rubel\anaconda3\envs\visa\Lib\site-packages\pymongo\_csot.py:125, in apply.<locals>.csot_wrapper(self, *args, **kwargs)
#     123         with _TimeoutContext(timeout):
#     124             return func(self, *args, **kwargs)
# --> 125 return func(self, *args, **kwargs)
#
# File c:\Users\Rubel\anaconda3\envs\visa\Lib\site-packages\pymongo\synchronous\mongo_client.py:1938, in MongoClient._run_operation(self, operation, unpack_res, address)
#    1928     operation.reset()  # Reset op in case of retry.
#    1929     return server.run_operation(
#    1930         conn,
#    1931         operation,
#    (...)   1935         self,
#    1936     )
# -> 1938 return self._retryable_read(
#    1939     _cmd,
#    1940     operation.read_preference,
#    1941     operation.session,  # type: ignore[arg-type]
#    1942     address=address,
#    1943     retryable=isinstance(operation, _Query),
#    1944     operation=operation.name,
#    1945 )
#
# File c:\Users\Rubel\anaconda3\envs\visa\Lib\site-packages\pymongo\synchronous\mongo_client.py:2047, in MongoClient._retryable_read(self, func, read_pref, session, operation, address, retryable, operation_id)
#    2042 # Ensure that the client supports retrying on reads and there is no session in
#    2043 # transaction, otherwise, we will not support retry behavior for this call.
#    2044 retryable = bool(
#    2045     retryable and self.options.retry_reads and not (session and session.in_transaction)
#    2046 )
# -> 2047 return self._retry_internal(
#    2048     func,
#    2049     session,
#    2050     None,
#    2051     operation,
#    2052     is_read=True,
#    2053     address=address,
#    2054     read_pref=read_pref,
#    2055     retryable=retryable,
#    2056     operation_id=operation_id,
#    2057 )
#
# File c:\Users\Rubel\anaconda3\envs\visa\Lib\site-packages\pymongo\_csot.py:125, in apply.<locals>.csot_wrapper(self, *args, **kwargs)
#     123         with _TimeoutContext(timeout):
#     124             return func(self, *args, **kwargs)
# --> 125 return func(self, *args, **kwargs)
#
# File c:\Users\Rubel\anaconda3\envs\visa\Lib\site-packages\pymongo\synchronous\mongo_client.py:2014, in MongoClient._retry_internal(self, func, session, bulk, operation, is_read, address, read_pref, retryable, operation_id)
#    1977 @_csot.apply
#    1978 def _retry_internal(
#    1979     self,
#    (...)   1988     operation_id: Optional[int] = None,
#    1989 ) -> T:
#    1990     """Internal retryable helper for all client transactions.
#    1991
#    1992     :param func: Callback function we want to retry
#    (...)   2001     :return: Output of the calling func()
#    2002     """
#    2003     return _ClientConnectionRetryable(
#    2004         mongo_client=self,
#    2005         func=func,
#    2006         bulk=bulk,
#    2007         operation=operation,
#    2008         is_read=is_read,
#    2009         session=session,
#    2010         read_pref=read_pref,
#    2011         address=address,
#    2012         retryable=retryable,
#    2013         operation_id=operation_id,
# -> 2014     ).run()
#
# File c:\Users\Rubel\anaconda3\envs\visa\Lib\site-packages\pymongo\synchronous\mongo_client.py:2765, in _ClientConnectionRetryable.run(self)
#    2763 self._check_last_error(check_csot=True)
#    2764 try:
# -> 2765     return self._read() if self._is_read else self._write()
#    2766 except ServerSelectionTimeoutError:
#    2767     # The application may think the write was never attempted
#    2768     # if we raise ServerSelectionTimeoutError on the retry
#    2769     # attempt. Raise the original exception instead.
#    2770     self._check_last_error()
#
# File c:\Users\Rubel\anaconda3\envs\visa\Lib\site-packages\pymongo\synchronous\mongo_client.py:2926, in _ClientConnectionRetryable._read(self)
#    2918 if self._retrying:
#    2919     _debug_log(
#    2920         _COMMAND_LOGGER,
#    2921         message=f"Retrying read attempt number {self._attempt_number}",
#    (...)   2924         operationId=self._operation_id,
#    2925     )
# -> 2926 return self._func(self._session, self._server, conn, read_pref)
#
# File c:\Users\Rubel\anaconda3\envs\visa\Lib\site-packages\pymongo\synchronous\mongo_client.py:1929, in MongoClient._run_operation.<locals>._cmd(_session, server, conn, read_preference)
#    1922 def _cmd(
#    1923     _session: Optional[ClientSession],
#    1924     server: Server,
#    1925     conn: Connection,
#    1926     read_preference: _ServerMode,
#    1927 ) -> Response:
#    1928     operation.reset()  # Reset op in case of retry.
# -> 1929     return server.run_operation(
#    1930         conn,
#    1931         operation,
#    1932         read_preference,
#    1933         self._event_listeners,
#    1934         unpack_res,
#    1935         self,
#    1936     )
#
# File c:\Users\Rubel\anaconda3\envs\visa\Lib\site-packages\pymongo\synchronous\helpers.py:47, in _handle_reauth.<locals>.inner(*args, **kwargs)
#      44 from pymongo.synchronous.pool import Connection
#      46 try:
# ---> 47     return func(*args, **kwargs)
#      48 except OperationFailure as exc:
#      49     if no_reauth:
#
# File c:\Users\Rubel\anaconda3\envs\visa\Lib\site-packages\pymongo\synchronous\server.py:208, in Server.run_operation(self, conn, operation, read_preference, listeners, unpack_res, client)
#     206 else:
#     207     conn.send_message(data, max_doc_size)
# --> 208     reply = conn.receive_message(request_id)
#     210 # Unpack and check for command errors.
#     211 if use_cmd:
#
# File c:\Users\Rubel\anaconda3\envs\visa\Lib\site-packages\pymongo\synchronous\pool.py:469, in Connection.receive_message(self, request_id)
#     467 # Catch KeyboardInterrupt, CancelledError, etc. and cleanup.
#     468 except BaseException as error:
# --> 469     self._raise_connection_failure(error)
#
# File c:\Users\Rubel\anaconda3\envs\visa\Lib\site-packages\pymongo\synchronous\pool.py:643, in Connection._raise_connection_failure(self, error)
#     641 if isinstance(error, (IOError, OSError, *SSLErrors)):
#     642     details = _get_timeout_details(self.opts)
# --> 643     _raise_connection_failure(self.address, error, timeout_details=details)
#     644 else:
#     645     raise
#
# File c:\Users\Rubel\anaconda3\envs\visa\Lib\site-packages\pymongo\pool_shared.py:150, in _raise_connection_failure(address, error, msg_prefix, timeout_details)
#     148     raise NetworkTimeout(msg) from error
#     149 else:
# --> 150     raise AutoReconnect(msg) from error
#
# AutoReconnect: ac-s2phry7-shard-00-01.ot2uzux.mongodb.net:27017: connection closed (configured timeouts: connectTimeoutMS: 20000.0ms)

# %%
if "_id" in df.columns.to_list():
    df = df.drop(columns=["_id"], axis = 1)
# Out:
# Empty DataFrame
# Columns: []
# Index: []
